# %% [markdown]
# ### 1. Import Dependencies

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import precision_score, recall_score, confusion_matrix

# %% [markdown]
# ### 2. Load dataset and split train test data

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42
)
# test_size=0.33 = DataTest 33%

# %% [markdown]
# ### 3. Train SVM with Hinge Loss and predict on DataTest

# %%
clf_hinge = SGDClassifier(loss='hinge', max_iter=1000, random_state=42)
clf_hinge.fit(X_train, y_train)

y_test_pred = clf_hinge.predict(X_test)

# %% [markdown]
# ### 4. Evaluate Model Performance

# %% [markdown]
# - precision: วัดว่าผลการคาดการณ์ผลบวกที่เป็นจริงมีสัดส่วนเท่าใด
# - recall: แสดงจำนวนผลบวกจริงที่ทำนายได้อย่างถูกต้อง
# - confusion_matrix:แสดงรายละเอียดประเภทของการคาดการณ์ที่ถูกต้องและไม่ถูกต้องในทุกคลาส

# %%
print("Precision score:", precision_score(
    y_test, y_test_pred, average='weighted'
))
print("Recall score:", recall_score(
    y_test, y_test_pred, average='weighted'
))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred))
# Out:
# Precision score: 0.7707407407407407
# Recall score: 0.7
# Confusion Matrix:
# [[19  0  0]
#  [ 4 11  0]
#  [ 4  7  5]]
